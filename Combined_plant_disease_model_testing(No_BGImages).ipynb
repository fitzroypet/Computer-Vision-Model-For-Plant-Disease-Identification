# %% [markdown]
# <a href="https://colab.research.google.com/github/fitzroypet/Detecting-Plant-Disease-using-MobileNet/blob/main/Combined_plant_disease_model_testing(No_BGImages).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Preprocess Test Images

# %%
from keras.preprocessing.image import ImageDataGenerator

# Specify test dataset directory
test_dir = '/content/drive/MyDrive/Output/test'

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
img_width,img_height =224,224
input_shape=(img_width,img_height,3)
batch_size =32

test_generator = test_datagen.flow_from_directory(test_dir,target_size=(img_width,img_height),batch_size=batch_size)
# Out:
# Found 1486 images belonging to 10 classes.

# %%
# Get images and labels batch from validation dataset generator
import numpy as np

test_image_batch, test_label_batch = next(iter(test_generator))
true_label_ids = np.argmax(test_label_batch, axis=-1)

print("Test batch shape:", test_image_batch.shape)
# Out:
# Test batch shape: (32, 224, 224, 3)

# %%
# Generate dataset labels

dataset_labels = sorted(test_generator.class_indices.items(), key=lambda pair:pair[1])
dataset_labels = np.array([key.title() for key, value in dataset_labels])
print(dataset_labels)
# Out:
# ['Tomato___Bacterial_Spot' 'Tomato___Early_Blight' 'Tomato___Late_Blight'
#  'Tomato___Leaf_Mold' 'Tomato___Septoria_Leaf_Spot'
#  'Tomato___Spider_Mites Two-Spotted_Spider_Mite' 'Tomato___Target_Spot'
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus' 'Tomato___Tomato_Mosaic_Virus'
#  'Tomato___Healthy']

# %% [markdown]
# # Generate prediction for Model 2 (Tomato with BG)

# %%
import tensorflow as tf

# Specify model path
model2 = "/content/drive/MyDrive/model2-outputmobilenetof8epoch.tflite"

# Load the TFLite model (with background) and allocate tensors.
interpreter_2 = tf.lite.Interpreter(model_path=model2)

# Get input and output tensors.
input_details_2 = interpreter_2.get_input_details()
output_details_2 = interpreter_2.get_output_details()

print("== Input details (Bg) ==")
print("name:", input_details_2[0]['name'])
print("shape:", input_details_2[0]['shape'])
print("type:", input_details_2[0]['dtype'])

print("\n== Output details (Model2) ==")
print("name:", output_details_2[0]['name'])
print("shape:", output_details_2[0]['shape'])
print("type:", output_details_2[0]['dtype'])
# Out:
# == Input details (Bg) ==
# name: serving_default_mobilenet_1.00_224_input:0
# shape: [  1 224 224   3]
# type: <class 'numpy.float32'>
#
# == Output details (Model2) ==
# name: StatefulPartitionedCall:0
# shape: [ 1 10]
# type: <class 'numpy.float32'>

# %% [markdown]
# Resize input and output tensors shapes
# Input shape of loaded TFLite model is 1x224x224x3, what means that we can make predictions for single image.
#
# Let's resize input and output tensors, so we can make predictions for batch of 32 images.

# %%
# Resize model 2 (with bg)

interpreter_2.resize_tensor_input(input_details_2[0]['index'], (32, 224, 224, 3))
interpreter_2.resize_tensor_input(output_details_2[0]['index'], (32, 10))
interpreter_2.allocate_tensors()

input_details_2 = interpreter_2.get_input_details()
output_details_2 = interpreter_2.get_output_details()

print("== Input details (model 2) ==")
print("name:", input_details_2[0]['name'])
print("shape:", input_details_2[0]['shape'])
print("type:", input_details_2[0]['dtype'])

print("\n== Output details (model 2) ==")
print("name:", output_details_2[0]['name'])
print("shape:", output_details_2[0]['shape'])
print("type:", output_details_2[0]['dtype'])
# Out:
# == Input details (model 2) ==
# name: serving_default_mobilenet_1.00_224_input:0
# shape: [ 32 224 224   3]
# type: <class 'numpy.float32'>
#
# == Output details (model 2) ==
# name: StatefulPartitionedCall:0
# shape: [32 10]
# type: <class 'numpy.float32'>

# %%
# Get model 2 predictions

interpreter_2.set_tensor(input_details_2[0]['index'], test_image_batch)
interpreter_2.invoke()

model2_predictions = interpreter_2.get_tensor(output_details_2[0]['index'])
print("Prediction results shape:", model2_predictions.shape)
# Out:
# Prediction results shape: (32, 10)

# %%
# Convert model 2 prediction results to Pandas dataframe, for better visualization

import pandas as pd
model2_pred_dataframe = pd.DataFrame(model2_predictions)
model2_pred_dataframe.columns = dataset_labels

print("Model 2 prediction results for the first elements")
model2_pred_dataframe.head()
# Out:
# Model 2 prediction results for the first elements
#    Tomato___Bacterial_Spot  Tomato___Early_Blight  Tomato___Late_Blight  \
# 0             2.280944e-02               0.561292          6.148633e-02
# 1             2.178410e-06               0.009260          1.706605e-04
# 2             4.448997e-05               0.053468          6.781459e-03
# 3             9.981046e-01               0.000246          1.992873e-08
# 4             1.936136e-07               0.000004          1.295502e-04
#
#    Tomato___Leaf_Mold  Tomato___Septoria_Leaf_Spot  \
# 0        2.878951e-01                     0.060758
# 1        1.958460e-03                     0.988586
# 2        8.888891e-01                     0.044327
# 3        3.646335e-08                     0.000271
# 4        2.935581e-05                     0.000004
#
#    Tomato___Spider_Mites Two-Spotted_Spider_Mite  Tomato___Target_Spot  \
# 0                                   1.565359e-04              0.000351
# 1                                   8.363880e-08              0.000005
# 2                                   2.774192e-03              0.000153
# 3                                   7.818929e-06              0.001370
# 4                                   4.068453e-06              0.000002
#
#    Tomato___Tomato_Yellow_Leaf_Curl_Virus  Tomato___Tomato_Mosaic_Virus  \
# 0                            1.952890e-03                  2.990294e-03
# 1                            6.576560e-06                  1.148482e-05
# 2                            4.207424e-05                  3.425634e-03
# 3                            2.703357e-07                  2.072868e-09
# 4                            9.989970e-01                  8.289024e-04
#
#    Tomato___Healthy
# 0      3.079463e-04
# 1      1.521585e-07
# 2      9.466940e-05
# 3      5.712109e-08
# 4      1.574067e-07

# %% [markdown]
# # Visualize Results for Model 2 (Tomato with BG)

# %%
# Print images batch and labels predictions for model 2

import matplotlib.pyplot as plt

model2_predicted_ids = np.argmax(model2_predictions, axis=-1)
model2_predicted_labels = dataset_labels[model2_predicted_ids]
model2_label_id = np.argmax(test_label_batch, axis=-1)

plt.figure(figsize=(10,15))
plt.subplots_adjust(hspace=0.5)
for n in range(30):
  plt.subplot(10,3,n+1)
  plt.imshow(test_image_batch[n])
  color = "green" if model2_predicted_ids[n] == true_label_ids[n] else "red"
  plt.title(model2_predicted_labels[n].title(), color=color)
  plt.axis('off')
_ = plt.suptitle("Predictions for Model 2 (Green: Correct, Red: Incorrect)")

# %% [markdown]
# ## Generate predictions for Model 3 (Tomato without BG)

# %%
# Specify model path for model without image background
model3 = "/content/drive/MyDrive/model3-outputmobilenetof8epoch.tflite"

# Load the TFLite model (no background) and allocate tensors.
interpreter_3 = tf.lite.Interpreter(model_path=model3)

# Get input and output tensors.
input_details_3 = interpreter_3.get_input_details()
output_details_3 = interpreter_3.get_output_details()

# Resize input and output tensors to handle batch of 32 images
interpreter_3.resize_tensor_input(input_details_3[0]['index'], (32, 224, 224, 3))
interpreter_3.resize_tensor_input(output_details_3[0]['index'], (32, 10))
interpreter_3.allocate_tensors()

print("== Input details (model3) ==")
print("name:", input_details_3[0]['name'])
print("shape:", input_details_3[0]['shape'])
print("type:", input_details_3[0]['dtype'])

print("\n== Output details (model3) ==")
print("name:", output_details_3[0]['name'])
print("shape:", output_details_3[0]['shape'])
print("type:", output_details_3[0]['dtype'])
# Out:
# == Input details (model3) ==
# name: serving_default_mobilenet_1.00_224_input:0
# shape: [  1 224 224   3]
# type: <class 'numpy.float32'>
#
# == Output details (model3) ==
# name: StatefulPartitionedCall:0
# shape: [ 1 10]
# type: <class 'numpy.float32'>

# %%
# Run inference
interpreter_3.set_tensor(input_details_3[0]['index'], test_image_batch)

interpreter_3.invoke()

model3_predictions = interpreter_3.get_tensor(output_details_3[0]['index'])
print("\nPrediction results shape:", model3_predictions.shape)
# Out:
# Prediction results shape: (32, 10)

# %%
# Print images batch and labels predictions for Model 3

import matplotlib.pyplot as plt

model3_predicted_ids = np.argmax(model3_predictions, axis=-1)
model3_predicted_labels = dataset_labels[model3_predicted_ids]
model3_label_id = np.argmax(test_label_batch, axis=-1)

plt.figure(figsize=(10,15))
plt.subplots_adjust(hspace=0.5)
for n in range(30):
  plt.subplot(10,3,n+1)
  plt.imshow(test_image_batch[n])
  color = "green" if model3_predicted_ids[n] == true_label_ids[n] else "red"
  plt.title(model3_predicted_labels[n].title(), color=color)
  plt.axis('off')
_ = plt.suptitle("Predictions for Model 3 (Green: Correct, Red: Incorrect)")

# %%
# Convert Model 3 prediction results to Pandas dataframe, for better visualization

model3_pred_dataframe = pd.DataFrame(model3_predictions)
model3_pred_dataframe.columns = dataset_labels

print("Model 3 prediction results for the first elements")
model3_pred_dataframe.head()
# Out:
# Model 3 prediction results for the first elements
#    Tomato___Bacterial_Spot  Tomato___Early_Blight  Tomato___Late_Blight  \
# 0                 0.000287               0.258183              0.740906
# 1                 0.004251               0.000131              0.013197
# 2                 0.000098               0.140814              0.000392
# 3                 0.121350               0.000050              0.001613
# 4                 0.000001               0.000062              0.003327
#
#    Tomato___Leaf_Mold  Tomato___Septoria_Leaf_Spot  \
# 0            0.000129                     0.000485
# 1            0.000789                     0.981626
# 2            0.011314                     0.021933
# 3            0.000009                     0.873913
# 4            0.000449                     0.000004
#
#    Tomato___Spider_Mites Two-Spotted_Spider_Mite  Tomato___Target_Spot  \
# 0                                   9.868945e-07          4.388535e-06
# 1                                   5.214646e-06          5.976622e-07
# 2                                   5.689186e-01          3.786962e-04
# 3                                   2.104625e-05          5.979146e-04
# 4                                   9.916876e-06          7.383191e-07
#
#    Tomato___Tomato_Yellow_Leaf_Curl_Virus  Tomato___Tomato_Mosaic_Virus  \
# 0                            4.202640e-06                  2.605164e-08
# 1                            2.724091e-07                  5.265547e-10
# 2                            2.556634e-01                  2.440554e-04
# 3                            5.532837e-05                  3.157873e-06
# 4                            9.960758e-01                  6.953265e-05
#
#    Tomato___Healthy
# 0      5.518690e-08
# 1      5.448646e-09
# 2      2.443364e-04
# 3      2.387062e-03
# 4      5.863556e-07

# %% [markdown]
# ##Compare prediction results
#
# Now we will use Pandas to visualize results from both models and find differences between them.

# %%
# Concatenate results from both models

all_models_dataframe = pd.concat([model2_pred_dataframe, 
                                  model3_pred_dataframe], 
                                 keys=['Model 2', 'Model 3'],
                                 axis='columns')
all_models_dataframe.head()
# Out:
#                   Model 2                                             \
#   Tomato___Bacterial_Spot Tomato___Early_Blight Tomato___Late_Blight
# 0            2.280944e-02              0.561292         6.148633e-02
# 1            2.178410e-06              0.009260         1.706605e-04
# 2            4.448997e-05              0.053468         6.781459e-03
# 3            9.981046e-01              0.000246         1.992873e-08
# 4            1.936136e-07              0.000004         1.295502e-04
#
#                                                   \
#   Tomato___Leaf_Mold Tomato___Septoria_Leaf_Spot
# 0       2.878951e-01                    0.060758
# 1       1.958460e-03                    0.988586
# 2       8.888891e-01                    0.044327
# 3       3.646335e-08                    0.000271
# 4       2.935581e-05                    0.000004
#
#                                                                       \
#   Tomato___Spider_Mites Two-Spotted_Spider_Mite Tomato___Target_Spot
# 0                                  1.565359e-04             0.000351
# 1                                  8.363880e-08             0.000005
# 2                                  2.774192e-03             0.000153
# 3                                  7.818929e-06             0.001370
# 4                                  4.068453e-06             0.000002
#
#                                                                        \
#   Tomato___Tomato_Yellow_Leaf_Curl_Virus Tomato___Tomato_Mosaic_Virus
# 0                           1.952890e-03                 2.990294e-03
# 1                           6.576560e-06                 1.148482e-05
# 2                           4.207424e-05                 3.425634e-03
# 3                           2.703357e-07                 2.072868e-09
# 4                           9.989970e-01                 8.289024e-04
#
#                                    Model 3                        \
#   Tomato___Healthy Tomato___Bacterial_Spot Tomato___Early_Blight
# 0     3.079463e-04                0.000287              0.258183
# 1     1.521585e-07                0.004251              0.000131
# 2     9.466940e-05                0.000098              0.140814
# 3     5.712109e-08                0.121350              0.000050
# 4     1.574067e-07                0.000001              0.000062
#
#                                                                        \
#   Tomato___Late_Blight Tomato___Leaf_Mold Tomato___Septoria_Leaf_Spot
# 0             0.740906           0.000129                    0.000485
# 1             0.013197           0.000789                    0.981626
# 2             0.000392           0.011314                    0.021933
# 3             0.001613           0.000009                    0.873913
# 4             0.003327           0.000449                    0.000004
#
#                                                                       \
#   Tomato___Spider_Mites Two-Spotted_Spider_Mite Tomato___Target_Spot
# 0                                  9.868945e-07         4.388535e-06
# 1                                  5.214646e-06         5.976622e-07
# 2                                  5.689186e-01         3.786962e-04
# 3                                  2.104625e-05         5.979146e-04
# 4                                  9.916876e-06         7.383191e-07
#
#                                                                        \
#   Tomato___Tomato_Yellow_Leaf_Curl_Virus Tomato___Tomato_Mosaic_Virus
# 0                           4.202640e-06                 2.605164e-08
# 1                           2.724091e-07                 5.265547e-10
# 2                           2.556634e-01                 2.440554e-04
# 3                           5.532837e-05                 3.157873e-06
# 4                           9.960758e-01                 6.953265e-05
#
#
#   Tomato___Healthy
# 0     5.518690e-08
# 1     5.448646e-09
# 2     2.443364e-04
# 3     2.387062e-03
# 4     5.863556e-07

# %%
# Swap columns to have a side by side comparison

all_models_dataframe = all_models_dataframe.swaplevel(axis='columns')[model2_pred_dataframe.columns]
all_models_dataframe.head()
# Out:
#   Tomato___Bacterial_Spot           Tomato___Early_Blight            \
#                   Model 2   Model 3               Model 2   Model 3
# 0            2.280944e-02  0.000287              0.561292  0.258183
# 1            2.178410e-06  0.004251              0.009260  0.000131
# 2            4.448997e-05  0.000098              0.053468  0.140814
# 3            9.981046e-01  0.121350              0.000246  0.000050
# 4            1.936136e-07  0.000001              0.000004  0.000062
#
#   Tomato___Late_Blight           Tomato___Leaf_Mold            \
#                Model 2   Model 3            Model 2   Model 3
# 0         6.148633e-02  0.740906       2.878951e-01  0.000129
# 1         1.706605e-04  0.013197       1.958460e-03  0.000789
# 2         6.781459e-03  0.000392       8.888891e-01  0.011314
# 3         1.992873e-08  0.001613       3.646335e-08  0.000009
# 4         1.295502e-04  0.003327       2.935581e-05  0.000449
#
#   Tomato___Septoria_Leaf_Spot            \
#                       Model 2   Model 3
# 0                    0.060758  0.000485
# 1                    0.988586  0.981626
# 2                    0.044327  0.021933
# 3                    0.000271  0.873913
# 4                    0.000004  0.000004
#
#   Tomato___Spider_Mites Two-Spotted_Spider_Mite                \
#                                         Model 2       Model 3
# 0                                  1.565359e-04  9.868945e-07
# 1                                  8.363880e-08  5.214646e-06
# 2                                  2.774192e-03  5.689186e-01
# 3                                  7.818929e-06  2.104625e-05
# 4                                  4.068453e-06  9.916876e-06
#
#   Tomato___Target_Spot               Tomato___Tomato_Yellow_Leaf_Curl_Virus  \
#                Model 2       Model 3                                Model 2
# 0             0.000351  4.388535e-06                           1.952890e-03
# 1             0.000005  5.976622e-07                           6.576560e-06
# 2             0.000153  3.786962e-04                           4.207424e-05
# 3             0.001370  5.979146e-04                           2.703357e-07
# 4             0.000002  7.383191e-07                           9.989970e-01
#
#                 Tomato___Tomato_Mosaic_Virus               Tomato___Healthy  \
#         Model 3                      Model 2       Model 3          Model 2
# 0  4.202640e-06                 2.990294e-03  2.605164e-08     3.079463e-04
# 1  2.724091e-07                 1.148482e-05  5.265547e-10     1.521585e-07
# 2  2.556634e-01                 3.425634e-03  2.440554e-04     9.466940e-05
# 3  5.532837e-05                 2.072868e-09  3.157873e-06     5.712109e-08
# 4  9.960758e-01                 8.289024e-04  6.953265e-05     1.574067e-07
#
#
#         Model 3
# 0  5.518690e-08
# 1  5.448646e-09
# 2  2.443364e-04
# 3  2.387062e-03
# 4  5.863556e-07

# %%
# Highlight model 3 predictions that are different from model 2

def highlight_diff(data, color='grey'):
    attr = 'background-color: {}'.format(color)
    other = data.xs('Model 2', axis='columns', level=-1)
    return pd.DataFrame(np.where(data.ne(other, level=0), attr, ''),
                        index=data.index, columns=data.columns)

all_models_dataframe.style.apply(highlight_diff, axis=None)
# Out:
# <style type="text/css">
# #T_61d62_row0_col1, #T_61d62_row0_col3, #T_61d62_row0_col5, #T_61d62_row0_col7, #T_61d62_row0_col9, #T_61d62_row0_col11, #T_61d62_row0_col13, #T_61d62_row0_col15, #T_61d62_row0_col17, #T_61d62_row0_col19, #T_61d62_row1_col1, #T_61d62_row1_col3, #T_61d62_row1_col5, #T_61d62_row1_col7, #T_61d62_row1_col9, #T_61d62_row1_col11, #T_61d62_row1_col13, #T_61d62_row1_col15, #T_61d62_row1_col17, #T_61d62_row1_col19, #T_61d62_row2_col1, #T_61d62_row2_col3, #T_61d62_row2_col5, #T_61d62_row2_col7, #T_61d62_row2_col9, #T_61d62_row2_col11, #T_61d62_row2_col13, #T_61d62_row2_col15, #T_61d62_row2_col17, #T_61d62_row2_col19, #T_61d62_row3_col1, #T_61d62_row3_col3, #T_61d62_row3_col5, #T_61d62_row3_col7, #T_61d62_row3_col9, #T_61d62_row3_col11, #T_61d62_row3_col13, #T_61d62_row3_col15, #T_61d62_row3_col17, #T_61d62_row3_col19, #T_61d62_row4_col1, #T_61d62_row4_col3, #T_61d62_row4_col5, #T_61d62_row4_col7, #T_61d62_row4_col9, #T_61d62_row4_col11, #T_61d62_row4_col13, #T_61d62_row4_col15, #T_61d62_row4_col17, #T_61d62_row4_col19, #T_61d62_row5_col1, #T_61d62_row5_col3, #T_61d62_row5_col5, #T_61d62_row5_col7, #T_61d62_row5_col9, #T_61d62_row5_col11, #T_61d62_row5_col13, #T_61d62_row5_col15, #T_61d62_row5_col17, #T_61d62_row5_col19, #T_61d62_row6_col1, #T_61d62_row6_col3, #T_61d62_row6_col5, #T_61d62_row6_col7, #T_61d62_row6_col9, #T_61d62_row6_col11, #T_61d62_row6_col13, #T_61d62_row6_col15, #T_61d62_row6_col17, #T_61d62_row6_col19, #T_61d62_row7_col1, #T_61d62_row7_col3, #T_61d62_row7_col5, #T_61d62_row7_col7, #T_61d62_row7_col9, #T_61d62_row7_col11, #T_61d62_row7_col13, #T_61d62_row7_col15, #T_61d62_row7_col17, #T_61d62_row7_col19, #T_61d62_row8_col1, #T_61d62_row8_col3, #T_61d62_row8_col5, #T_61d62_row8_col7, #T_61d62_row8_col9, #T_61d62_row8_col11, #T_61d62_row8_col13, #T_61d62_row8_col15, #T_61d62_row8_col17, #T_61d62_row8_col19, #T_61d62_row9_col1, #T_61d62_row9_col3, #T_61d62_row9_col5, #T_61d62_row9_col7, #T_61d62_row9_col9, #T_61d62_row9_col11, #T_61d62_row9_col13, #T_61d62_row9_col15, #T_61d62_row9_col17, #T_61d62_row9_col19, #T_61d62_row10_col1, #T_61d62_row10_col3, #T_61d62_row10_col5, #T_61d62_row10_col7, #T_61d62_row10_col9, #T_61d62_row10_col11, #T_61d62_row10_col13, #T_61d62_row10_col15, #T_61d62_row10_col17, #T_61d62_row10_col19, #T_61d62_row11_col1, #T_61d62_row11_col3, #T_61d62_row11_col5, #T_61d62_row11_col7, #T_61d62_row11_col9, #T_61d62_row11_col11, #T_61d62_row11_col13, #T_61d62_row11_col15, #T_61d62_row11_col17, #T_61d62_row11_col19, #T_61d62_row12_col1, #T_61d62_row12_col3, #T_61d62_row12_col5, #T_61d62_row12_col7, #T_61d62_row12_col9, #T_61d62_row12_col11, #T_61d62_row12_col13, #T_61d62_row12_col15, #T_61d62_row12_col17, #T_61d62_row12_col19, #T_61d62_row13_col1, #T_61d62_row13_col3, #T_61d62_row13_col5, #T_61d62_row13_col7, #T_61d62_row13_col9, #T_61d62_row13_col11, #T_61d62_row13_col13, #T_61d62_row13_col15, #T_61d62_row13_col17, #T_61d62_row13_col19, #T_61d62_row14_col1, #T_61d62_row14_col3, #T_61d62_row14_col5, #T_61d62_row14_col7, #T_61d62_row14_col9, #T_61d62_row14_col11, #T_61d62_row14_col13, #T_61d62_row14_col15, #T_61d62_row14_col17, #T_61d62_row14_col19, #T_61d62_row15_col1, #T_61d62_row15_col3, #T_61d62_row15_col5, #T_61d62_row15_col7, #T_61d62_row15_col9, #T_61d62_row15_col11, #T_61d62_row15_col13, #T_61d62_row15_col15, #T_61d62_row15_col17, #T_61d62_row15_col19, #T_61d62_row16_col1, #T_61d62_row16_col3, #T_61d62_row16_col5, #T_61d62_row16_col7, #T_61d62_row16_col9, #T_61d62_row16_col11, #T_61d62_row16_col13, #T_61d62_row16_col15, #T_61d62_row16_col17, #T_61d62_row16_col19, #T_61d62_row17_col1, #T_61d62_row17_col3, #T_61d62_row17_col5, #T_61d62_row17_col7, #T_61d62_row17_col9, #T_61d62_row17_col11, #T_61d62_row17_col13, #T_61d62_row17_col15, #T_61d62_row17_col17, #T_61d62_row17_col19, #T_61d62_row18_col1, #T_61d62_row18_col3, #T_61d62_row18_col5, #T_61d62_row18_col7, #T_61d62_row18_col9, #T_61d62_row18_col11, #T_61d62_row18_col13, #T_61d62_row18_col15, #T_61d62_row18_col17, #T_61d62_row18_col19, #T_61d62_row19_ ...
#   background-color: grey;
# }
# </style>
# <table id="T_61d62_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="2">Tomato___Bacterial_Spot</th>
#       <th class="col_heading level0 col2" colspan="2">Tomato___Early_Blight</th>
#       <th class="col_heading level0 col4" colspan="2">Tomato___Late_Blight</th>
#       <th class="col_heading level0 col6" colspan="2">Tomato___Leaf_Mold</th>
#       <th class="col_heading level0 col8" colspan="2">Tomato___Septoria_Leaf_Spot</th>
#       <th class="col_heading level0 col10" colspan="2">Tomato___Spider_Mites Two-Spotted_Spider_Mite</th>
#       <th class="col_heading level0 col12" colspan="2">Tomato___Target_Spot</th>
#       <th class="col_heading level0 col14" colspan="2">Tomato___Tomato_Yellow_Leaf_Curl_Virus</th>
#       <th class="col_heading level0 col16" colspan="2">Tomato___Tomato_Mosaic_Virus</th>
#       <th class="col_heading level0 col18" colspan="2">Tomato___Healthy</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" >Model 2</th>
#       <th class="col_heading level1 col1" >Model 3</th>
#       <th class="co

# %% [markdown]
# As we can see, in most cases predictions are different between all models, usually by small factors. High-confidence predictions between TensorFlow and TensorFlow Lite models are very close to each other (in some cases there are even similar).
# Quantized model outstands the most, but this is the cost of optimizations (model weights 3-4 times less).
#
# To make prediction results even more readable, let's simplify dataframes, to show only the highest-score prediction and the corresponding label.

# %%
# Concatenation of argmax and max value for each row
def max_values_only(data):
  argmax_col = np.argmax(data, axis=1).reshape(-1, 1)
  max_col = np.max(data, axis=1).reshape(-1, 1)
  return np.concatenate([argmax_col, max_col], axis=1)

# Build simplified prediction tables
model2_pred_simplified = max_values_only(model2_predictions)
model3_pred_simplified = max_values_only(model3_predictions)

# %%
# Build DataFrames and present example
columns_names = ["Label_id", "Confidence"]
model2_simple_dataframe = pd.DataFrame(model2_pred_simplified)
model2_simple_dataframe.columns = columns_names

model3_simple_dataframe = pd.DataFrame(model3_pred_simplified)
model3_simple_dataframe.columns = columns_names

model2_simple_dataframe.head()
model3_simple_dataframe.head()
# Out:
#    Label_id  Confidence
# 0       2.0    0.740906
# 1       4.0    0.981626
# 2       5.0    0.568919
# 3       4.0    0.873913
# 4       7.0    0.996076

# %%
# Concatenate results from all models
all_models_simple_dataframe = pd.concat([model2_simple_dataframe,
                                         model3_simple_dataframe], 
                                        keys=['Model 2', 'Model 3'],
                                        axis='columns')

# Swap columns for side-by-side comparison
all_models_simple_dataframe = all_models_simple_dataframe.swaplevel(axis='columns')[model2_simple_dataframe.columns]

# Highlight differences
all_models_simple_dataframe.style.apply(highlight_diff, axis=None)
# Out:
# <style type="text/css">
# #T_1624b_row0_col1, #T_1624b_row0_col3, #T_1624b_row1_col3, #T_1624b_row2_col1, #T_1624b_row2_col3, #T_1624b_row3_col1, #T_1624b_row3_col3, #T_1624b_row4_col3, #T_1624b_row5_col1, #T_1624b_row5_col3, #T_1624b_row6_col1, #T_1624b_row6_col3, #T_1624b_row7_col1, #T_1624b_row7_col3, #T_1624b_row8_col1, #T_1624b_row8_col3, #T_1624b_row9_col1, #T_1624b_row9_col3, #T_1624b_row10_col1, #T_1624b_row10_col3, #T_1624b_row11_col1, #T_1624b_row11_col3, #T_1624b_row12_col1, #T_1624b_row12_col3, #T_1624b_row13_col1, #T_1624b_row13_col3, #T_1624b_row14_col3, #T_1624b_row15_col1, #T_1624b_row15_col3, #T_1624b_row16_col1, #T_1624b_row16_col3, #T_1624b_row17_col3, #T_1624b_row18_col3, #T_1624b_row19_col1, #T_1624b_row19_col3, #T_1624b_row20_col3, #T_1624b_row21_col1, #T_1624b_row21_col3, #T_1624b_row22_col1, #T_1624b_row22_col3, #T_1624b_row23_col3, #T_1624b_row24_col3, #T_1624b_row25_col1, #T_1624b_row25_col3, #T_1624b_row26_col3, #T_1624b_row27_col3, #T_1624b_row28_col3, #T_1624b_row29_col3, #T_1624b_row30_col1, #T_1624b_row30_col3, #T_1624b_row31_col3 {
#   background-color: grey;
# }
# </style>
# <table id="T_1624b_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="2">Label_id</th>
#       <th class="col_heading level0 col2" colspan="2">Confidence</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" >Model 2</th>
#       <th class="col_heading level1 col1" >Model 3</th>
#       <th class="col_heading level1 col2" >Model 2</th>
#       <th class="col_heading level1 col3" >Model 3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1624b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1624b_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_1624b_row0_col1" class="data row0 col1" >2.000000</td>
#       <td id="T_1624b_row0_col2" class="data row0 col2" >0.561292</td>
#       <td id="T_1624b_row0_col3" class="data row0 col3" >0.740906</td>
#     </tr>
#     <tr>
#       <th id="T_1624b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1624b_row1_col0" class="data row1 col0" >4.000000</td>
#       <td id="T_1624b_row1_col1" class="data row1 col1" >4.000000</td>
#       <td id="T_1624b_row1_col2" class="data row1 col2" >0.988586</td>
#       <td id="T_1624b_row1_col3" class="data row1 col3" >0.981626</td>
#     </tr>
#     <tr>
#       <th id="T_1624b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1624b_row2_col0" class="data row2 col0" >3.000000</td>
#       <td id="T_1624b_row2_col1" class="data row2 col1" >5.000000</td>
#       <td id="T_1624b_row2_col2" class="data row2 col2" >0.888889</td>
#       <td id="T_1624b_row2_col3" class="data row2 col3" >0.568919</td>
#     </tr>
#     <tr>
#       <th id="T_1624b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1624b_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_1624b_row3_col1" class="data row3 col1" >4.000000</td>
#       <td id="T_1624b_row3_col2" class="data row3 col2" >0.998105</td>
#       <td id="T_1624b_row3_col3" class="data row3 col3" >0.873913</td>
#     </tr>
#     <tr>
#       <th id="T_1624b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1624b_row4_col0" class="data row4 col0" >7.000000</td>
#       <td id="T_1624b_row4_col1" class="data row4 col1" >7.000000</td>
#       <td id="T_1624b_row4_col2" class="data row4 col2" >0.998997</td>
#       <td id="T_1624b_row4_col3" class="data row4 col3" >0.996076</td>
#     </tr>
#     <tr>
#       <th id="T_1624b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1624b_row5_col0" class="data row5 col0" >0.000000</td>
#       <td id="T_1624b_row5_col1" class="data row5 col1" >4.000000</td>
#       <td id="T_1624b_row5_col2" class="data row5 col2" >0.996784</td>
#       <td id="T_1624b_row5_col3" class="data row5 col3" >0.974480</td>
#     </tr>
#     <tr>
#       <th id="T_1624b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1624b_row6_col0" class="data row6 col0" >9.000000</td>
#       <td id="T_1624b_row6_col1" class="data row6 col1" >1.000000</td>
#       <td id="T_1624b_row6_col2" class="data row6 col2" >0.979669</td>
#       <td id="T_1624b_row6_col3" class="data row6 col3" >0.796901</td>
#     </tr>
#     <tr>
#       <th id="T_1624b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1624b_row7_col0" class="data row7 col0" >3.000000</td>
#       <td id="T_1624b_row7_col1" class="data row7 col1" >2.000000</td>
#       <td id="T_1624b_row7_col2" class="data row7 col2" >0.997947</td>
#       <td id="T_1624b_row7_col3" class="data row7 col3" >0.992852</td>
#     </tr>
#     <tr>
#       <th id="T_1624b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1624b_row8_col0" class="data row8 col0" >0.000000</td>
#       <td id="T_1624b_row8_col1" class="data row8 col1" >4.000000</td>
#       <td id="T_1624b_row8_col2" class="data row8 col2" >0.996990</td>
#       <td id="T_1624b_row8_col3" class="data row8 col3" >0.947557</td>
#     </tr>
#     <tr>
#       <th id="T_1624b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1624b_row9_col0" class="data row9 col0" >8.000000</td>
#       <td id="T_1624b_row9_col1" class="data row9 col1" >1.000000</td>
#       <td id="T_1624b_row9_col2" class="data row9 col2" >0.994150</td>
#       <td id="T_1624b_row9_col3" class="data row9 col3" >0.714579</td>
#     </tr>
#     <tr>
#       <th id="T_1624b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1624b_row10_col0" class="data row10 col0" >6.000000</td>
#       <td id="T_1624b_row10_col1" class="data row10 col1" >1.000000</td>
#       <td id="T_1624b_row10_col2" class="data row10 col2" >0.998693</td>
#       <td id="T_1624b_row10_col3" class="data row10 col3" >0.787780</td>
#     </tr>
#     <tr>
#       <th id="T_1624b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1624b_row11_col0" class="data row11 col0" >0.000000</td>
#       <td id="T_1624b_row11_col1" class="data row11 col1" >5.000000</td>
#       <td id="T_1624b_row11_col2" class="data row11 col2" >0.999159</td>
#       <td id="T_1624b_row11_col3" class="data row11 col3" >0.995838</td>
#     </tr>
#     <tr>
#       <th id="T_1624b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1624b_row12_col0" class="data row12 col0" >6.000000</td>
#       <td id="T_1624b_row12_col1" class="data row12 col1" >4.000000</td>
#       <td id="T_1624b_row12_col2" class="data row12 col2" >0.644036</td>
#       <td id="T_1624b_row12_col3" class="data row12 col3" >0.286881</td>
#     </tr>
#     <tr>
#       <th id="T_1624b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_1624b_row13_col0" class="data row13 col0" >0.000000</td>
#       <td id="T_1624b_row13_col1" class="data row13 col1" >5.000000</td>
#       <td id="T_1624b_row13_col2" class="data row13 col2" >0.999945</td>
#       <td id="T_1624b_row13_col3" class="data row13 col3" >0.995523</td>
#     </tr>
#     <tr>
#       <th id="T_1624b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_1624b_row14_col0" class="data row14 col0" >6.000000</td>
#       <td id="T_1624b_row14_col1" class="data row14 col1" >6.000000</td>
#       <td id="T_1624b_row14_col2" class="data row14 col2" >0.997245</td>
#       <td id="T_1624b_row14_col3" class="data row14 col3" >0.782945</td>
#     </tr>
#     <tr>
#       <th id="T_1624b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_1624b_row15_col0" class="data row15 col0" >0.000000</td>
#       <td id="T_1624b_row15_col1" class="data row15 col1" >2.000000</td>
#       <td id="T_1624b_row15_col2" class="data row15 col2" >0.999503</td>
#       <td id="T_1624b_row15_col3" class="data row15 col3" >0.696684</td>
#     </tr>
#     <tr>
#       <th id="T_1624b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_1624b_row16_col0" class="data row16 col0" >9.000000</td>
#       <td id="T_1624b_row16_col1" class="data row16
