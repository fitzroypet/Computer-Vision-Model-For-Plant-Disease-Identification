# %% [markdown]
# <a href="https://colab.research.google.com/github/fitzroypet/Detecting-Plant-Disease-using-MobileNet/blob/main/Combined_plant_disease_model_testing(BGImages).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Preprocess Test Images

# %%
from keras.preprocessing.image import ImageDataGenerator

# Specify test dataset directory
test_dir = '/content/drive/MyDrive/Output_bg/test'

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
img_width,img_height =224,224
input_shape=(img_width,img_height,3)
batch_size =32

test_generator = test_datagen.flow_from_directory(test_dir,target_size=(img_width,img_height),batch_size=batch_size)
# Out:
# Found 1906 images belonging to 10 classes.

# %%
# Get images and labels batch from validation dataset generator
import numpy as np

test_image_batch, test_label_batch = next(iter(test_generator))
true_label_ids = np.argmax(test_label_batch, axis=-1)

print("Test batch shape:", test_image_batch.shape)
# Out:
# Test batch shape: (32, 224, 224, 3)

# %%
# Generate dataset labels

dataset_labels = sorted(test_generator.class_indices.items(), key=lambda pair:pair[1])
dataset_labels = np.array([key.title() for key, value in dataset_labels])
print(dataset_labels)
# Out:
# ['Tomato___Bacterial_Spot' 'Tomato___Early_Blight' 'Tomato___Late_Blight'
#  'Tomato___Leaf_Mold' 'Tomato___Septoria_Leaf_Spot'
#  'Tomato___Spider_Mites Two-Spotted_Spider_Mite' 'Tomato___Target_Spot'
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus' 'Tomato___Tomato_Mosaic_Virus'
#  'Tomato___Healthy']

# %% [markdown]
# # Generate prediction for Model 2 (Tomato with BG)

# %%
import tensorflow as tf

# Specify model path
model2 = "/content/drive/MyDrive/model2-outputmobilenetof8epoch.tflite"

# Load the TFLite model (with background) and allocate tensors.
interpreter_2 = tf.lite.Interpreter(model_path=model2)

# Get input and output tensors.
input_details_2 = interpreter_2.get_input_details()
output_details_2 = interpreter_2.get_output_details()

print("== Input details (Bg) ==")
print("name:", input_details_2[0]['name'])
print("shape:", input_details_2[0]['shape'])
print("type:", input_details_2[0]['dtype'])

print("\n== Output details (Model2) ==")
print("name:", output_details_2[0]['name'])
print("shape:", output_details_2[0]['shape'])
print("type:", output_details_2[0]['dtype'])
# Out:
# == Input details (Bg) ==
# name: serving_default_mobilenet_1.00_224_input:0
# shape: [  1 224 224   3]
# type: <class 'numpy.float32'>
#
# == Output details (Model2) ==
# name: StatefulPartitionedCall:0
# shape: [ 1 10]
# type: <class 'numpy.float32'>

# %% [markdown]
# Resize input and output tensors shapes
# Input shape of loaded TFLite model is 1x224x224x3, what means that we can make predictions for single image.
#
# Let's resize input and output tensors, so we can make predictions for batch of 32 images.

# %%
# Resize model 2 (with bg)

interpreter_2.resize_tensor_input(input_details_2[0]['index'], (32, 224, 224, 3))
interpreter_2.resize_tensor_input(output_details_2[0]['index'], (32, 10))
interpreter_2.allocate_tensors()

input_details_2 = interpreter_2.get_input_details()
output_details_2 = interpreter_2.get_output_details()

print("== Input details (model 2) ==")
print("name:", input_details_2[0]['name'])
print("shape:", input_details_2[0]['shape'])
print("type:", input_details_2[0]['dtype'])

print("\n== Output details (model 2) ==")
print("name:", output_details_2[0]['name'])
print("shape:", output_details_2[0]['shape'])
print("type:", output_details_2[0]['dtype'])
# Out:
# == Input details (model 2) ==
# name: serving_default_mobilenet_1.00_224_input:0
# shape: [ 32 224 224   3]
# type: <class 'numpy.float32'>
#
# == Output details (model 2) ==
# name: StatefulPartitionedCall:0
# shape: [32 10]
# type: <class 'numpy.float32'>

# %%
# Get model 2 predictions

interpreter_2.set_tensor(input_details_2[0]['index'], test_image_batch)
interpreter_2.invoke()

model2_predictions = interpreter_2.get_tensor(output_details_2[0]['index'])
print("Prediction results shape:", model2_predictions.shape)
# Out:
# Prediction results shape: (32, 10)

# %%
# Convert model 2 prediction results to Pandas dataframe, for better visualization

import pandas as pd
model2_pred_dataframe = pd.DataFrame(model2_predictions)
model2_pred_dataframe.columns = dataset_labels

print("Model 2 prediction results for the first elements")
model2_pred_dataframe.head()
# Out:
# Model 2 prediction results for the first elements
#    Tomato___Bacterial_Spot  Tomato___Early_Blight  Tomato___Late_Blight  \
# 0                 0.000333               0.137127              0.061134
# 1                 0.000003               0.001645              0.000185
# 2                 0.000124               0.000110              0.000032
# 3                 0.060219               0.010036              0.907104
# 4                 0.000175               0.402809              0.421986
#
#    Tomato___Leaf_Mold  Tomato___Septoria_Leaf_Spot  \
# 0            0.000148                     0.001748
# 1            0.000052                     0.000034
# 2            0.000042                     0.999687
# 3            0.000790                     0.013026
# 4            0.031977                     0.073982
#
#    Tomato___Spider_Mites Two-Spotted_Spider_Mite  Tomato___Target_Spot  \
# 0                                   2.495076e-05          6.025604e-02
# 1                                   5.808779e-06          1.558879e-05
# 2                                   1.327610e-07          5.630243e-08
# 3                                   5.353476e-03          2.406343e-03
# 4                                   7.024662e-05          6.739418e-02
#
#    Tomato___Tomato_Yellow_Leaf_Curl_Virus  Tomato___Tomato_Mosaic_Virus  \
# 0                                0.000003                  1.342548e-06
# 1                                0.998038                  2.050533e-05
# 2                                0.000003                  5.061216e-07
# 3                                0.000752                  1.925009e-06
# 4                                0.000879                  5.583404e-05
#
#    Tomato___Healthy
# 0      7.392251e-01
# 1      4.694522e-07
# 2      1.973418e-06
# 3      3.102050e-04
# 4      6.725391e-04

# %% [markdown]
# # Visualize Results for Model 2 (Tomato with BG)

# %%
# Print images batch and labels predictions for model 2

import matplotlib.pyplot as plt

model2_predicted_ids = np.argmax(model2_predictions, axis=-1)
model2_predicted_labels = dataset_labels[model2_predicted_ids]
model2_label_id = np.argmax(test_label_batch, axis=-1)

plt.figure(figsize=(10,15))
plt.subplots_adjust(hspace=0.5)
for n in range(30):
  plt.subplot(10,3,n+1)
  plt.imshow(test_image_batch[n])
  color = "green" if model2_predicted_ids[n] == true_label_ids[n] else "red"
  plt.title(model2_predicted_labels[n].title(), color=color)
  plt.axis('off')
_ = plt.suptitle("Predictions for Model 2 (green: correct, red: incorrect)")

# %% [markdown]
# ## Generate predictions for Model 3 (Tomato without BG)

# %%
# Specify model path for model without image background
model3 = "/content/drive/MyDrive/model3-outputmobilenetof8epoch.tflite"

# Load the TFLite model (no background) and allocate tensors.
interpreter_3 = tf.lite.Interpreter(model_path=model3)

# Get input and output tensors.
input_details_3 = interpreter_3.get_input_details()
output_details_3 = interpreter_3.get_output_details()

# Resize input and output tensors to handle batch of 32 images
interpreter_3.resize_tensor_input(input_details_3[0]['index'], (32, 224, 224, 3))
interpreter_3.resize_tensor_input(output_details_3[0]['index'], (32, 10))
interpreter_3.allocate_tensors()

print("== Input details (model3) ==")
print("name:", input_details_3[0]['name'])
print("shape:", input_details_3[0]['shape'])
print("type:", input_details_3[0]['dtype'])

print("\n== Output details (model3) ==")
print("name:", output_details_3[0]['name'])
print("shape:", output_details_3[0]['shape'])
print("type:", output_details_3[0]['dtype'])
# Out:
# == Input details (model3) ==
# name: serving_default_mobilenet_1.00_224_input:0
# shape: [  1 224 224   3]
# type: <class 'numpy.float32'>
#
# == Output details (model3) ==
# name: StatefulPartitionedCall:0
# shape: [ 1 10]
# type: <class 'numpy.float32'>

# %%
# Run inference
interpreter_3.set_tensor(input_details_3[0]['index'], test_image_batch)

interpreter_3.invoke()

model3_predictions = interpreter_3.get_tensor(output_details_3[0]['index'])
print("\nPrediction results shape:", model3_predictions.shape)
# Out:
# Prediction results shape: (32, 10)

# %%
# Print images batch and labels predictions for Model 3

import matplotlib.pyplot as plt

model3_predicted_ids = np.argmax(model3_predictions, axis=-1)
model3_predicted_labels = dataset_labels[model3_predicted_ids]
model3_label_id = np.argmax(test_label_batch, axis=-1)

plt.figure(figsize=(10,15))
plt.subplots_adjust(hspace=0.5)
for n in range(30):
  plt.subplot(10,3,n+1)
  plt.imshow(test_image_batch[n])
  color = "green" if model3_predicted_ids[n] == true_label_ids[n] else "red"
  plt.title(model3_predicted_labels[n].title(), color=color)
  plt.axis('off')
_ = plt.suptitle("Predictions for Model 3 (green: correct, red: incorrect)")

# %%
# Convert Model 3 prediction results to Pandas dataframe, for better visualization

model3_pred_dataframe = pd.DataFrame(model3_predictions)
model3_pred_dataframe.columns = dataset_labels

print("Model 3 prediction results for the first elements")
model3_pred_dataframe.head()
# Out:
# Model 3 prediction results for the first elements
#    Tomato___Bacterial_Spot  Tomato___Early_Blight  Tomato___Late_Blight  \
# 0             9.138216e-07           3.492540e-05          4.046599e-05
# 1             4.077806e-10           6.182282e-10          3.045799e-07
# 2             7.939765e-08           2.880511e-08          1.716545e-08
# 3             5.268625e-06           9.856206e-05          7.082104e-04
# 4             2.017285e-06           4.508009e-06          1.266525e-07
#
#    Tomato___Leaf_Mold  Tomato___Septoria_Leaf_Spot  \
# 0        9.211803e-09                 1.171124e-06
# 1        3.991688e-10                 1.167429e-07
# 2        6.632906e-09                 3.857421e-10
# 3        9.982798e-01                 1.563078e-04
# 4        1.644957e-06                 9.999906e-01
#
#    Tomato___Spider_Mites Two-Spotted_Spider_Mite  Tomato___Target_Spot  \
# 0                                   2.473222e-06          1.321648e-03
# 1                                   1.554921e-11          1.323929e-07
# 2                                   4.478286e-08          9.664435e-09
# 3                                   3.714183e-04          4.701413e-05
# 4                                   1.358459e-07          3.888406e-07
#
#    Tomato___Tomato_Yellow_Leaf_Curl_Virus  Tomato___Tomato_Mosaic_Virus  \
# 0                            1.009804e-05                  1.422031e-10
# 1                            9.999247e-01                  6.649042e-08
# 2                            9.999998e-01                  4.902866e-09
# 3                            3.153775e-04                  1.789395e-05
# 4                            9.559485e-08                  4.416873e-07
#
#    Tomato___Healthy
# 0      9.985883e-01
# 1      7.467052e-05
# 2      7.272186e-10
# 3      1.791543e-07
# 4      1.245502e-09

# %% [markdown]
# ##Compare prediction results
#
# Now we will use Pandas to visualize results from both models and find differences between them.

# %%
# Concatenate results from both models

all_models_dataframe = pd.concat([model2_pred_dataframe, 
                                  model3_pred_dataframe], 
                                 keys=['Model 2', 'Model 3'],
                                 axis='columns')
all_models_dataframe.head()
# Out:
#                   Model 2                                             \
#   Tomato___Bacterial_Spot Tomato___Early_Blight Tomato___Late_Blight
# 0                0.000333              0.137127             0.061134
# 1                0.000003              0.001645             0.000185
# 2                0.000124              0.000110             0.000032
# 3                0.060219              0.010036             0.907104
# 4                0.000175              0.402809             0.421986
#
#                                                   \
#   Tomato___Leaf_Mold Tomato___Septoria_Leaf_Spot
# 0           0.000148                    0.001748
# 1           0.000052                    0.000034
# 2           0.000042                    0.999687
# 3           0.000790                    0.013026
# 4           0.031977                    0.073982
#
#                                                                       \
#   Tomato___Spider_Mites Two-Spotted_Spider_Mite Tomato___Target_Spot
# 0                                  2.495076e-05         6.025604e-02
# 1                                  5.808779e-06         1.558879e-05
# 2                                  1.327610e-07         5.630243e-08
# 3                                  5.353476e-03         2.406343e-03
# 4                                  7.024662e-05         6.739418e-02
#
#                                                                        \
#   Tomato___Tomato_Yellow_Leaf_Curl_Virus Tomato___Tomato_Mosaic_Virus
# 0                               0.000003                 1.342548e-06
# 1                               0.998038                 2.050533e-05
# 2                               0.000003                 5.061216e-07
# 3                               0.000752                 1.925009e-06
# 4                               0.000879                 5.583404e-05
#
#                                    Model 3                        \
#   Tomato___Healthy Tomato___Bacterial_Spot Tomato___Early_Blight
# 0     7.392251e-01            9.138216e-07          3.492540e-05
# 1     4.694522e-07            4.077806e-10          6.182282e-10
# 2     1.973418e-06            7.939765e-08          2.880511e-08
# 3     3.102050e-04            5.268625e-06          9.856206e-05
# 4     6.725391e-04            2.017285e-06          4.508009e-06
#
#                                                                        \
#   Tomato___Late_Blight Tomato___Leaf_Mold Tomato___Septoria_Leaf_Spot
# 0         4.046599e-05       9.211803e-09                1.171124e-06
# 1         3.045799e-07       3.991688e-10                1.167429e-07
# 2         1.716545e-08       6.632906e-09                3.857421e-10
# 3         7.082104e-04       9.982798e-01                1.563078e-04
# 4         1.266525e-07       1.644957e-06                9.999906e-01
#
#                                                                       \
#   Tomato___Spider_Mites Two-Spotted_Spider_Mite Tomato___Target_Spot
# 0                                  2.473222e-06         1.321648e-03
# 1                                  1.554921e-11         1.323929e-07
# 2                                  4.478286e-08         9.664435e-09
# 3                                  3.714183e-04         4.701413e-05
# 4                                  1.358459e-07         3.888406e-07
#
#                                                                        \
#   Tomato___Tomato_Yellow_Leaf_Curl_Virus Tomato___Tomato_Mosaic_Virus
# 0                           1.009804e-05                 1.422031e-10
# 1                           9.999247e-01                 6.649042e-08
# 2                           9.999998e-01                 4.902866e-09
# 3                           3.153775e-04                 1.789395e-05
# 4                           9.559485e-08                 4.416873e-07
#
#
#   Tomato___Healthy
# 0     9.985883e-01
# 1     7.467052e-05
# 2     7.272186e-10
# 3     1.791543e-07
# 4     1.245502e-09

# %%
# Swap columns to have a side by side comparison

all_models_dataframe = all_models_dataframe.swaplevel(axis='columns')[model2_pred_dataframe.columns]
all_models_dataframe.head()
# Out:
#   Tomato___Bacterial_Spot               Tomato___Early_Blight                \
#                   Model 2       Model 3               Model 2       Model 3
# 0                0.000333  9.138216e-07              0.137127  3.492540e-05
# 1                0.000003  4.077806e-10              0.001645  6.182282e-10
# 2                0.000124  7.939765e-08              0.000110  2.880511e-08
# 3                0.060219  5.268625e-06              0.010036  9.856206e-05
# 4                0.000175  2.017285e-06              0.402809  4.508009e-06
#
#   Tomato___Late_Blight               Tomato___Leaf_Mold                \
#                Model 2       Model 3            Model 2       Model 3
# 0             0.061134  4.046599e-05           0.000148  9.211803e-09
# 1             0.000185  3.045799e-07           0.000052  3.991688e-10
# 2             0.000032  1.716545e-08           0.000042  6.632906e-09
# 3             0.907104  7.082104e-04           0.000790  9.982798e-01
# 4             0.421986  1.266525e-07           0.031977  1.644957e-06
#
#   Tomato___Septoria_Leaf_Spot                \
#                       Model 2       Model 3
# 0                    0.001748  1.171124e-06
# 1                    0.000034  1.167429e-07
# 2                    0.999687  3.857421e-10
# 3                    0.013026  1.563078e-04
# 4                    0.073982  9.999906e-01
#
#   Tomato___Spider_Mites Two-Spotted_Spider_Mite                \
#                                         Model 2       Model 3
# 0                                  2.495076e-05  2.473222e-06
# 1                                  5.808779e-06  1.554921e-11
# 2                                  1.327610e-07  4.478286e-08
# 3                                  5.353476e-03  3.714183e-04
# 4                                  7.024662e-05  1.358459e-07
#
#   Tomato___Target_Spot               Tomato___Tomato_Yellow_Leaf_Curl_Virus  \
#                Model 2       Model 3                                Model 2
# 0         6.025604e-02  1.321648e-03                               0.000003
# 1         1.558879e-05  1.323929e-07                               0.998038
# 2         5.630243e-08  9.664435e-09                               0.000003
# 3         2.406343e-03  4.701413e-05                               0.000752
# 4         6.739418e-02  3.888406e-07                               0.000879
#
#                 Tomato___Tomato_Mosaic_Virus               Tomato___Healthy  \
#         Model 3                      Model 2       Model 3          Model 2
# 0  1.009804e-05                 1.342548e-06  1.422031e-10     7.392251e-01
# 1  9.999247e-01                 2.050533e-05  6.649042e-08     4.694522e-07
# 2  9.999998e-01                 5.061216e-07  4.902866e-09     1.973418e-06
# 3  3.153775e-04                 1.925009e-06  1.789395e-05     3.102050e-04
# 4  9.559485e-08                 5.583404e-05  4.416873e-07     6.725391e-04
#
#
#         Model 3
# 0  9.985883e-01
# 1  7.467052e-05
# 2  7.272186e-10
# 3  1.791543e-07
# 4  1.245502e-09

# %%
# Highlight model 3 predictions that are different from model 2

def highlight_diff(data, color='grey'):
    attr = 'background-color: {}'.format(color)
    other = data.xs('Model 2', axis='columns', level=-1)
    return pd.DataFrame(np.where(data.ne(other, level=0), attr, ''),
                        index=data.index, columns=data.columns)

all_models_dataframe.style.apply(highlight_diff, axis=None)
# Out:
# <style type="text/css">
# #T_0bc8e_row0_col1, #T_0bc8e_row0_col3, #T_0bc8e_row0_col5, #T_0bc8e_row0_col7, #T_0bc8e_row0_col9, #T_0bc8e_row0_col11, #T_0bc8e_row0_col13, #T_0bc8e_row0_col15, #T_0bc8e_row0_col17, #T_0bc8e_row0_col19, #T_0bc8e_row1_col1, #T_0bc8e_row1_col3, #T_0bc8e_row1_col5, #T_0bc8e_row1_col7, #T_0bc8e_row1_col9, #T_0bc8e_row1_col11, #T_0bc8e_row1_col13, #T_0bc8e_row1_col15, #T_0bc8e_row1_col17, #T_0bc8e_row1_col19, #T_0bc8e_row2_col1, #T_0bc8e_row2_col3, #T_0bc8e_row2_col5, #T_0bc8e_row2_col7, #T_0bc8e_row2_col9, #T_0bc8e_row2_col11, #T_0bc8e_row2_col13, #T_0bc8e_row2_col15, #T_0bc8e_row2_col17, #T_0bc8e_row2_col19, #T_0bc8e_row3_col1, #T_0bc8e_row3_col3, #T_0bc8e_row3_col5, #T_0bc8e_row3_col7, #T_0bc8e_row3_col9, #T_0bc8e_row3_col11, #T_0bc8e_row3_col13, #T_0bc8e_row3_col15, #T_0bc8e_row3_col17, #T_0bc8e_row3_col19, #T_0bc8e_row4_col1, #T_0bc8e_row4_col3, #T_0bc8e_row4_col5, #T_0bc8e_row4_col7, #T_0bc8e_row4_col9, #T_0bc8e_row4_col11, #T_0bc8e_row4_col13, #T_0bc8e_row4_col15, #T_0bc8e_row4_col17, #T_0bc8e_row4_col19, #T_0bc8e_row5_col1, #T_0bc8e_row5_col3, #T_0bc8e_row5_col5, #T_0bc8e_row5_col7, #T_0bc8e_row5_col9, #T_0bc8e_row5_col11, #T_0bc8e_row5_col13, #T_0bc8e_row5_col15, #T_0bc8e_row5_col17, #T_0bc8e_row5_col19, #T_0bc8e_row6_col1, #T_0bc8e_row6_col3, #T_0bc8e_row6_col5, #T_0bc8e_row6_col7, #T_0bc8e_row6_col9, #T_0bc8e_row6_col11, #T_0bc8e_row6_col13, #T_0bc8e_row6_col15, #T_0bc8e_row6_col17, #T_0bc8e_row6_col19, #T_0bc8e_row7_col1, #T_0bc8e_row7_col3, #T_0bc8e_row7_col5, #T_0bc8e_row7_col7, #T_0bc8e_row7_col9, #T_0bc8e_row7_col11, #T_0bc8e_row7_col13, #T_0bc8e_row7_col15, #T_0bc8e_row7_col17, #T_0bc8e_row7_col19, #T_0bc8e_row8_col1, #T_0bc8e_row8_col3, #T_0bc8e_row8_col5, #T_0bc8e_row8_col7, #T_0bc8e_row8_col9, #T_0bc8e_row8_col11, #T_0bc8e_row8_col13, #T_0bc8e_row8_col15, #T_0bc8e_row8_col17, #T_0bc8e_row8_col19, #T_0bc8e_row9_col1, #T_0bc8e_row9_col3, #T_0bc8e_row9_col5, #T_0bc8e_row9_col7, #T_0bc8e_row9_col9, #T_0bc8e_row9_col11, #T_0bc8e_row9_col13, #T_0bc8e_row9_col15, #T_0bc8e_row9_col17, #T_0bc8e_row9_col19, #T_0bc8e_row10_col1, #T_0bc8e_row10_col3, #T_0bc8e_row10_col5, #T_0bc8e_row10_col7, #T_0bc8e_row10_col9, #T_0bc8e_row10_col11, #T_0bc8e_row10_col13, #T_0bc8e_row10_col15, #T_0bc8e_row10_col17, #T_0bc8e_row10_col19, #T_0bc8e_row11_col1, #T_0bc8e_row11_col3, #T_0bc8e_row11_col5, #T_0bc8e_row11_col7, #T_0bc8e_row11_col9, #T_0bc8e_row11_col11, #T_0bc8e_row11_col13, #T_0bc8e_row11_col15, #T_0bc8e_row11_col17, #T_0bc8e_row11_col19, #T_0bc8e_row12_col1, #T_0bc8e_row12_col3, #T_0bc8e_row12_col5, #T_0bc8e_row12_col7, #T_0bc8e_row12_col9, #T_0bc8e_row12_col11, #T_0bc8e_row12_col13, #T_0bc8e_row12_col15, #T_0bc8e_row12_col17, #T_0bc8e_row12_col19, #T_0bc8e_row13_col1, #T_0bc8e_row13_col3, #T_0bc8e_row13_col5, #T_0bc8e_row13_col7, #T_0bc8e_row13_col9, #T_0bc8e_row13_col11, #T_0bc8e_row13_col13, #T_0bc8e_row13_col15, #T_0bc8e_row13_col17, #T_0bc8e_row13_col19, #T_0bc8e_row14_col1, #T_0bc8e_row14_col3, #T_0bc8e_row14_col5, #T_0bc8e_row14_col7, #T_0bc8e_row14_col9, #T_0bc8e_row14_col11, #T_0bc8e_row14_col13, #T_0bc8e_row14_col15, #T_0bc8e_row14_col17, #T_0bc8e_row14_col19, #T_0bc8e_row15_col1, #T_0bc8e_row15_col3, #T_0bc8e_row15_col5, #T_0bc8e_row15_col7, #T_0bc8e_row15_col9, #T_0bc8e_row15_col11, #T_0bc8e_row15_col13, #T_0bc8e_row15_col15, #T_0bc8e_row15_col17, #T_0bc8e_row15_col19, #T_0bc8e_row16_col1, #T_0bc8e_row16_col3, #T_0bc8e_row16_col5, #T_0bc8e_row16_col7, #T_0bc8e_row16_col9, #T_0bc8e_row16_col11, #T_0bc8e_row16_col13, #T_0bc8e_row16_col15, #T_0bc8e_row16_col17, #T_0bc8e_row16_col19, #T_0bc8e_row17_col1, #T_0bc8e_row17_col3, #T_0bc8e_row17_col5, #T_0bc8e_row17_col7, #T_0bc8e_row17_col9, #T_0bc8e_row17_col11, #T_0bc8e_row17_col13, #T_0bc8e_row17_col15, #T_0bc8e_row17_col17, #T_0bc8e_row17_col19, #T_0bc8e_row18_col1, #T_0bc8e_row18_col3, #T_0bc8e_row18_col5, #T_0bc8e_row18_col7, #T_0bc8e_row18_col9, #T_0bc8e_row18_col11, #T_0bc8e_row18_col13, #T_0bc8e_row18_col15, #T_0bc8e_row18_col17, #T_0bc8e_row18_col19, #T_0bc8e_row19_ ...
#   background-color: grey;
# }
# </style>
# <table id="T_0bc8e_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="2">Tomato___Bacterial_Spot</th>
#       <th class="col_heading level0 col2" colspan="2">Tomato___Early_Blight</th>
#       <th class="col_heading level0 col4" colspan="2">Tomato___Late_Blight</th>
#       <th class="col_heading level0 col6" colspan="2">Tomato___Leaf_Mold</th>
#       <th class="col_heading level0 col8" colspan="2">Tomato___Septoria_Leaf_Spot</th>
#       <th class="col_heading level0 col10" colspan="2">Tomato___Spider_Mites Two-Spotted_Spider_Mite</th>
#       <th class="col_heading level0 col12" colspan="2">Tomato___Target_Spot</th>
#       <th class="col_heading level0 col14" colspan="2">Tomato___Tomato_Yellow_Leaf_Curl_Virus</th>
#       <th class="col_heading level0 col16" colspan="2">Tomato___Tomato_Mosaic_Virus</th>
#       <th class="col_heading level0 col18" colspan="2">Tomato___Healthy</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" >Model 2</th>
#       <th class="col_heading level1 col1" >Model 3</th>
#       <th class="co

# %% [markdown]
# As we can see, in most cases predictions are different between all models, usually by small factors. High-confidence predictions between TensorFlow and TensorFlow Lite models are very close to each other (in some cases there are even similar).
# Quantized model outstands the most, but this is the cost of optimizations (model weights 3-4 times less).
#
# To make prediction results even more readable, let's simplify dataframes, to show only the highest-score prediction and the corresponding label.

# %%
# Concatenation of argmax and max value for each row
def max_values_only(data):
  argmax_col = np.argmax(data, axis=1).reshape(-1, 1)
  max_col = np.max(data, axis=1).reshape(-1, 1)
  return np.concatenate([argmax_col, max_col], axis=1)

# Build simplified prediction tables
model2_pred_simplified = max_values_only(model2_predictions)
model3_pred_simplified = max_values_only(model3_predictions)

# %%
# Build DataFrames and present example
columns_names = ["Label_id", "Confidence"]
model2_simple_dataframe = pd.DataFrame(model2_pred_simplified)
model2_simple_dataframe.columns = columns_names

model3_simple_dataframe = pd.DataFrame(model3_pred_simplified)
model3_simple_dataframe.columns = columns_names

model2_simple_dataframe.head()
model3_simple_dataframe.head()
# Out:
#    Label_id  Confidence
# 0       9.0    0.998588
# 1       7.0    0.999925
# 2       7.0    1.000000
# 3       3.0    0.998280
# 4       4.0    0.999991

# %%
# Concatenate results from all models
all_models_simple_dataframe = pd.concat([model2_simple_dataframe,
                                         model3_simple_dataframe], 
                                        keys=['Model 2', 'Model 3'],
                                        axis='columns')

# Swap columns for side-by-side comparison
all_models_simple_dataframe = all_models_simple_dataframe.swaplevel(axis='columns')[model2_simple_dataframe.columns]

# Highlight differences
all_models_simple_dataframe.style.apply(highlight_diff, axis=None)
# Out:
# <style type="text/css">
# #T_18146_row0_col3, #T_18146_row1_col3, #T_18146_row2_col1, #T_18146_row2_col3, #T_18146_row3_col1, #T_18146_row3_col3, #T_18146_row4_col1, #T_18146_row4_col3, #T_18146_row5_col1, #T_18146_row5_col3, #T_18146_row6_col3, #T_18146_row7_col3, #T_18146_row8_col3, #T_18146_row9_col1, #T_18146_row9_col3, #T_18146_row10_col3, #T_18146_row11_col3, #T_18146_row12_col1, #T_18146_row12_col3, #T_18146_row13_col3, #T_18146_row14_col3, #T_18146_row15_col1, #T_18146_row15_col3, #T_18146_row16_col1, #T_18146_row16_col3, #T_18146_row17_col1, #T_18146_row17_col3, #T_18146_row18_col3, #T_18146_row19_col3, #T_18146_row20_col3, #T_18146_row21_col1, #T_18146_row21_col3, #T_18146_row22_col1, #T_18146_row22_col3, #T_18146_row23_col3, #T_18146_row24_col3, #T_18146_row25_col1, #T_18146_row25_col3, #T_18146_row26_col3, #T_18146_row27_col3, #T_18146_row28_col3, #T_18146_row29_col3, #T_18146_row30_col1, #T_18146_row30_col3, #T_18146_row31_col1, #T_18146_row31_col3 {
#   background-color: grey;
# }
# </style>
# <table id="T_18146_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="2">Label_id</th>
#       <th class="col_heading level0 col2" colspan="2">Confidence</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" >Model 2</th>
#       <th class="col_heading level1 col1" >Model 3</th>
#       <th class="col_heading level1 col2" >Model 2</th>
#       <th class="col_heading level1 col3" >Model 3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18146_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_18146_row0_col0" class="data row0 col0" >9.000000</td>
#       <td id="T_18146_row0_col1" class="data row0 col1" >9.000000</td>
#       <td id="T_18146_row0_col2" class="data row0 col2" >0.739225</td>
#       <td id="T_18146_row0_col3" class="data row0 col3" >0.998588</td>
#     </tr>
#     <tr>
#       <th id="T_18146_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_18146_row1_col0" class="data row1 col0" >7.000000</td>
#       <td id="T_18146_row1_col1" class="data row1 col1" >7.000000</td>
#       <td id="T_18146_row1_col2" class="data row1 col2" >0.998038</td>
#       <td id="T_18146_row1_col3" class="data row1 col3" >0.999925</td>
#     </tr>
#     <tr>
#       <th id="T_18146_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_18146_row2_col0" class="data row2 col0" >4.000000</td>
#       <td id="T_18146_row2_col1" class="data row2 col1" >7.000000</td>
#       <td id="T_18146_row2_col2" class="data row2 col2" >0.999687</td>
#       <td id="T_18146_row2_col3" class="data row2 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18146_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_18146_row3_col0" class="data row3 col0" >2.000000</td>
#       <td id="T_18146_row3_col1" class="data row3 col1" >3.000000</td>
#       <td id="T_18146_row3_col2" class="data row3 col2" >0.907104</td>
#       <td id="T_18146_row3_col3" class="data row3 col3" >0.998280</td>
#     </tr>
#     <tr>
#       <th id="T_18146_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_18146_row4_col0" class="data row4 col0" >2.000000</td>
#       <td id="T_18146_row4_col1" class="data row4 col1" >4.000000</td>
#       <td id="T_18146_row4_col2" class="data row4 col2" >0.421986</td>
#       <td id="T_18146_row4_col3" class="data row4 col3" >0.999991</td>
#     </tr>
#     <tr>
#       <th id="T_18146_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_18146_row5_col0" class="data row5 col0" >2.000000</td>
#       <td id="T_18146_row5_col1" class="data row5 col1" >7.000000</td>
#       <td id="T_18146_row5_col2" class="data row5 col2" >0.500679</td>
#       <td id="T_18146_row5_col3" class="data row5 col3" >0.994677</td>
#     </tr>
#     <tr>
#       <th id="T_18146_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_18146_row6_col0" class="data row6 col0" >9.000000</td>
#       <td id="T_18146_row6_col1" class="data row6 col1" >9.000000</td>
#       <td id="T_18146_row6_col2" class="data row6 col2" >0.995371</td>
#       <td id="T_18146_row6_col3" class="data row6 col3" >0.999957</td>
#     </tr>
#     <tr>
#       <th id="T_18146_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_18146_row7_col0" class="data row7 col0" >2.000000</td>
#       <td id="T_18146_row7_col1" class="data row7 col1" >2.000000</td>
#       <td id="T_18146_row7_col2" class="data row7 col2" >0.969069</td>
#       <td id="T_18146_row7_col3" class="data row7 col3" >0.999935</td>
#     </tr>
#     <tr>
#       <th id="T_18146_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_18146_row8_col0" class="data row8 col0" >6.000000</td>
#       <td id="T_18146_row8_col1" class="data row8 col1" >6.000000</td>
#       <td id="T_18146_row8_col2" class="data row8 col2" >0.568194</td>
#       <td id="T_18146_row8_col3" class="data row8 col3" >0.948072</td>
#     </tr>
#     <tr>
#       <th id="T_18146_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_18146_row9_col0" class="data row9 col0" >6.000000</td>
#       <td id="T_18146_row9_col1" class="data row9 col1" >9.000000</td>
#       <td id="T_18146_row9_col2" class="data row9 col2" >0.669023</td>
#       <td id="T_18146_row9_col3" class="data row9 col3" >0.993433</td>
#     </tr>
#     <tr>
#       <th id="T_18146_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_18146_row10_col0" class="data row10 col0" >3.000000</td>
#       <td id="T_18146_row10_col1" class="data row10 col1" >3.000000</td>
#       <td id="T_18146_row10_col2" class="data row10 col2" >0.281115</td>
#       <td id="T_18146_row10_col3" class="data row10 col3" >0.902834</td>
#     </tr>
#     <tr>
#       <th id="T_18146_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_18146_row11_col0" class="data row11 col0" >2.000000</td>
#       <td id="T_18146_row11_col1" class="data row11 col1" >2.000000</td>
#       <td id="T_18146_row11_col2" class="data row11 col2" >0.954990</td>
#       <td id="T_18146_row11_col3" class="data row11 col3" >0.998520</td>
#     </tr>
#     <tr>
#       <th id="T_18146_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_18146_row12_col0" class="data row12 col0" >0.000000</td>
#       <td id="T_18146_row12_col1" class="data row12 col1" >5.000000</td>
#       <td id="T_18146_row12_col2" class="data row12 col2" >0.937687</td>
#       <td id="T_18146_row12_col3" class="data row12 col3" >0.938377</td>
#     </tr>
#     <tr>
#       <th id="T_18146_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_18146_row13_col0" class="data row13 col0" >7.000000</td>
#       <td id="T_18146_row13_col1" class="data row13 col1" >7.000000</td>
#       <td id="T_18146_row13_col2" class="data row13 col2" >0.999955</td>
#       <td id="T_18146_row13_col3" class="data row13 col3" >0.999944</td>
#     </tr>
#     <tr>
#       <th id="T_18146_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_18146_row14_col0" class="data row14 col0" >0.000000</td>
#       <td id="T_18146_row14_col1" class="data row14 col1" >0.000000</td>
#       <td id="T_18146_row14_col2" class="data row14 col2" >0.998616</td>
#       <td id="T_18146_row14_col3" class="data row14 col3" >0.995547</td>
#     </tr>
#     <tr>
#       <th id="T_18146_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_18146_row15_col0" class="data row15 col0" >4.000000</td>
#       <td id="T_18146_row15_col1" class="data row15 col1" >2.000000</td>
#       <td id="T_18146_row15_col2" class="data row15 col2" >0.804528</td>
#       <td id="T_18146_row15_col3" class="data row15 col3" >0.999993</td>
#     </tr>
#     <tr>
#       <th id="T_18146_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_18146_row16_col0" class="data row16 col0" >2.000000</td>
#       <td id="T_18146_row16_col1" class="data row16 col1" >3.000000</td>
#       <td id="T_18146_row16_col2" class="data row16 col2" >0.996331</td>
#       <t
